# %% [markdown]
# <a href="https://colab.research.google.com/github/ahdrifai1234/data-science-2026/blob/main/Pertemuan1_Ahamd_Rifai_240401010260.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IDENTITAS
#
# NAMA  : Ahmad Rifai
#
# NIM   : 240401010260
#
# KELAS : IF403

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# SEL 2: Variabel dan tipe data dasar
nama = "Ahmad Rifai" # String
angkatan = 2026 # Integer
ipk = 4.00 # Float
aktif = True # Boolean
print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Ahmad Rifai", "Informatika", 2026)
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama : Ahmad Rifai
# Angkatan: 2026
# IPK : 4.0
# Aktif : True
#
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub
# Hai! Saya Ahmad Rifai dari Informatika, angkatan 2026.

# %% [markdown]
# ### Kesimpulan
#
# Notebook pada google collabs ini menyajikan pengenalan dasar Data Science menggunakan Python. Mempelajari konsep fundamental seperti variabel, tipe data, struktur data (list), perulangan, dan fungsi sederhana dalam Python. Ini adalah fondasi penting untuk memulai eksplorasi lebih lanjut dalam bidang Data Science.
